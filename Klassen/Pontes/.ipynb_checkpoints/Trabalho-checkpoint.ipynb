# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Exemplo:-Cálculo-da-laje-central" data-toc-modified-id="Exemplo:-Cálculo-da-laje-central-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exemplo: Cálculo da laje central</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Esquema-estrutural" data-toc-modified-id="Esquema-estrutural-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Esquema estrutural</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Cargas-permanentes" data-toc-modified-id="Cargas-permanentes-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Cargas permanentes</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momentos-fletores-devido-carga-permanente" data-toc-modified-id="Momentos-fletores-devido-carga-permanente-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Momentos fletores devido carga permanente</a></span></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Carregamento-móvel" data-toc-modified-id="Carregamento-móvel-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Carregamento móvel</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Direção-transversal" data-toc-modified-id="Direção-transversal-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Direção transversal</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Diagramas-de-momentos-fletores" data-toc-modified-id="Diagramas-de-momentos-fletores-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Diagramas de momentos fletores</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Seção-transversal" data-toc-modified-id="Seção-transversal-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Seção transversal</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momentos-fletores-nas-seções-de-cálculo-devido-a-carga-permanente" data-toc-modified-id="Momentos-fletores-nas-seções-de-cálculo-devido-a-carga-permanente-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Momentos fletores nas seções de cálculo devido a carga permanente</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momento-fletor-na-seção-de-cálculo,-devido-carga-móvel" data-toc-modified-id="Momento-fletor-na-seção-de-cálculo,-devido-carga-móvel-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Momento fletor na seção de cálculo, devido carga móvel</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Coeficiente-de-impacto-vertical" data-toc-modified-id="Coeficiente-de-impacto-vertical-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Coeficiente de impacto vertical</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Envoltório-momento-fletor" data-toc-modified-id="Envoltório-momento-fletor-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Envoltório momento fletor</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#DImensionamento-ao-momento-fletor" data-toc-modified-id="DImensionamento-ao-momento-fletor-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>DImensionamento ao momento fletor</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momentos-positivos" data-toc-modified-id="Momentos-positivos-1.4.7.1"><span class="toc-item-num">1.4.7.1&nbsp;&nbsp;</span>Momentos positivos</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momentos-negativos" data-toc-modified-id="Momentos-negativos-1.4.7.2"><span class="toc-item-num">1.4.7.2&nbsp;&nbsp;</span>Momentos negativos</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momento-positivos---Verificação-fadiga" data-toc-modified-id="Momento-positivos---Verificação-fadiga-1.4.7.3"><span class="toc-item-num">1.4.7.3&nbsp;&nbsp;</span>Momento positivos - Verificação fadiga</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momentos-negativos---Verificação-fadiga" data-toc-modified-id="Momentos-negativos---Verificação-fadiga-1.4.7.4"><span class="toc-item-num">1.4.7.4&nbsp;&nbsp;</span>Momentos negativos - Verificação fadiga</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Resumo-armadura-positiva" data-toc-modified-id="Resumo-armadura-positiva-1.4.7.5"><span class="toc-item-num">1.4.7.5&nbsp;&nbsp;</span>Resumo armadura positiva</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Resumo-armadura-negativa" data-toc-modified-id="Resumo-armadura-negativa-1.4.7.6"><span class="toc-item-num">1.4.7.6&nbsp;&nbsp;</span>Resumo armadura negativa</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Direção-longitudinal" data-toc-modified-id="Direção-longitudinal-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Direção longitudinal</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Envoltorio-dos-momentos-fletores" data-toc-modified-id="Envoltorio-dos-momentos-fletores-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Envoltorio dos momentos fletores</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Cálculo-da-laje-em-balanço" data-toc-modified-id="Cálculo-da-laje-em-balanço-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cálculo da laje em balanço</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Esquema-estrutural-e-seções-de-cálculo" data-toc-modified-id="Esquema-estrutural-e-seções-de-cálculo-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Esquema estrutural e seções de cálculo</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Cargas-permanentes" data-toc-modified-id="Cargas-permanentes-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Cargas permanentes</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Cálculo-das-cargas" data-toc-modified-id="Cálculo-das-cargas-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Cálculo das cargas</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momentos-fletores-nas-seções-de-cálculo,-devido-a-carga-permanente" data-toc-modified-id="Momentos-fletores-nas-seções-de-cálculo,-devido-a-carga-permanente-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Momentos fletores nas seções de cálculo, devido a carga permanente</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Seção-$S_1$" data-toc-modified-id="Seção-$S_1$-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>Seção $S_1$</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Seção-$S_2$" data-toc-modified-id="Seção-$S_2$-2.2.2.2"><span class="toc-item-num">2.2.2.2&nbsp;&nbsp;</span>Seção $S_2$</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Seção-$S_3$" data-toc-modified-id="Seção-$S_3$-2.2.2.3"><span class="toc-item-num">2.2.2.3&nbsp;&nbsp;</span>Seção $S_3$</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Cargas-móveis" data-toc-modified-id="Cargas-móveis-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Cargas móveis</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Momento-fletor-nas-seções-de-cálculo,-devido-a-carga-móvel" data-toc-modified-id="Momento-fletor-nas-seções-de-cálculo,-devido-a-carga-móvel-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Momento fletor nas seções de cálculo, devido a carga móvel</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Direção-transversal-('x')" data-toc-modified-id="Direção-transversal-('x')-2.3.1.1"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>Direção transversal ('x')</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Direção-longitudinal-('y')" data-toc-modified-id="Direção-longitudinal-('y')-2.3.1.2"><span class="toc-item-num">2.3.1.2&nbsp;&nbsp;</span>Direção longitudinal ('y')</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Direção-transversal-('x')" data-toc-modified-id="Direção-transversal-('x')-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Direção transversal ('x')</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Coeficiente-de-impacto-vertical" data-toc-modified-id="Coeficiente-de-impacto-vertical-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Coeficiente de impacto vertical</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Envoltório-dos-momentos-fletores" data-toc-modified-id="Envoltório-dos-momentos-fletores-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Envoltório dos momentos fletores</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Trabalho.ipynb#Dimensionamento-aos-momentos-fletores---direção-('y')" data-toc-modified-id="Dimensionamento-aos-momentos-fletores---direção-('y')-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Dimensionamento aos momentos fletores - direção ('y')</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Exemplo: Cálculo da laje central

# %%
# parametros de projeto
fck = 40
numero_vaos = 3
vao_central = 25
balanco = 6
vao_entre_longarinas = 7
largura_tabuleiro = 12

# %% [markdown]
# ## Esquema estrutural

# %%
import pandas as pd
import numpy as np

# distancia entre eixos do trem tipo
a = 2 #m

# distancia entre as longarinas
lx = vao_entre_longarinas #m

# considerar ly/lx = infinito
# ou seja ly >>> lx
# placa n27

# area de contato da roda do trem tipo
# vista lateral da roda
b1 = 0.2 #m
# vista frontal das 2 rodas
b2 = 0.5 #m

# espessura do pavimento
e = 0.085 # m

# altura da laje
h = 0.25 # m

# cargas dos pneus 
t1 = b1 + 2 * (e) + h
t2 = b2 + 2 * (e) + h
# transformar area de contato em um quadrado
t = np.sqrt((t1 + t2)) 

# Imprimir tabela de dados
df = pd.DataFrame(
    [t1, t2,t, t/a, lx/a],
    ['t1', 't2', 't', 't/a', 'lx/a']
)
df
# Out:
#              0
# t1    0.620000
# t2    0.920000
# t     1.240967
# t/a   0.620484
# lx/a  3.500000

# %% [markdown]
# ## Cargas permanentes

# %%
# Peso próprio da laje
altura_laje = 0.25 #m
peso_concreto = 2.5 #tf/m3
pp_laje = altura_laje * peso_concreto

# Peso próprio pavimento
altura_pavimento = 0.085 #m
peso_pavimento =  2.4 #tf/m3
pp_pavimento = altura_pavimento * peso_pavimento

# Peso total
g = pp_laje + pp_pavimento

# Imprimir tabela de dados
df = pd.DataFrame(
    [altura_laje, peso_concreto, pp_laje, altura_pavimento, peso_pavimento, pp_pavimento, g],
    ['altura_laje', "peso_concreto", 'pp_laje', 'altura_pavimento', 'peso_pavimento', 'pp_pavimento', 'g (tf/m2)']
)
df
# Out:
#                       0
# altura_laje       0.250
# peso_concreto     2.500
# pp_laje           0.625
# altura_pavimento  0.085
# peso_pavimento    2.400
# pp_pavimento      0.204
# g (tf/m2)         0.829

# %% [markdown]
# ### Momentos fletores devido carga permanente

# %%
# Valores da tabela da placa n 27
kxm = 0.0417 #tf
mxm = kxm * g * lx**2

kym = 0.0069 #tf         
mym = kym * g * lx**2

kxe = -0.0833 #tf
mxe = kxe * g * lx**2

# Imprimir tabela de dados
df_g = pd.DataFrame([
    [g],
    [lx],
        [kxm],
    [mxm],
        [kym],
    [mym],
        [kxe],
    [mxe]
],
    columns=['magnitude'],
    index=['g (tf/m2) ------------','lx (m)','$k_{xm}$','$M_{xm} (tf m/m)$','$k_{ym}$','$M_{ym} (tf m/m)$','$k_{xe}$', '$M_{xe} (tf m/m)$']
)
df_g
# Out:
#                         magnitude
# g (tf/m2) ------------   0.829000
# lx (m)                   7.000000
# $k_{xm}$                 0.041700
# $M_{xm} (tf m/m)$        1.693896
# $k_{ym}$                 0.006900
# $M_{ym} (tf m/m)$        0.280285
# $k_{xe}$                -0.083300
# $M_{xe} (tf m/m)$       -3.383729

# %% [markdown]
# ## Carregamento móvel

# %% [markdown]
# ## Direção transversal

# %%
# t/a arredondado
t_a = np.round(t/a, 2)

# valores da tabela
mxm_3_05 = 0.37
mxm_4_05 = 0.485
mxm_3_1 = 0.33
mxm_4_1 = 0.44
mxm_p_3 = 0.3
mxm_p_4 = 0.8
mxm_pl_3 = 0.33
mxm_pl_4 = 1.11

mym_3_05 = 0.179
mym_4_05 = 0.262
mym_3_1 = 0.141
mym_4_1 = 0.222
mym_p_3 = 0.05
mym_p_4 = 0.13
mym_pl_3 = 0.24
mym_pl_4 = 0.57

mxe_3_05 = 0.8
mxe_4_05 = 1.01
mxe_3_1 = 0.78
mxe_4_1 = 0.98
mxe_p_3 = 0.2
mxe_p_4 = 0.55
mxe_pl_3 = 0.8
mxe_pl_4 = 2.20

# valores medios
mxm_ta_3 = (mxm_3_05 + mxm_3_1)/2
mxm_ta_4 = (mxm_4_05 + mxm_4_1)/2

mym_ta_3 = (mym_3_05 + mym_3_1)/2
mym_ta_4 = (mym_4_05 + mym_4_1)/2

mxe_ta_3 = (mxe_3_05 + mxe_3_1)/2
mxe_ta_4 = (mxe_4_05 + mxe_4_1)/2

# valores interpolados
mxm_m = np.interp(lx/a, [3,4],[mxm_ta_3, mxm_ta_4])
mym_m = np.interp(lx/a, [3,4],[mym_ta_3, mym_ta_4])
mxe_m = np.interp(lx/a, [3,4],[mxe_ta_3, mxe_ta_4])
mxm_p = np.interp(lx/a, [3,4],[mxm_p_3, mxm_p_4])
mxm_pl = np.interp(lx/a, [3,4],[mxm_pl_3, mxm_pl_4])
mym_p = np.interp(lx/a, [3,4],[mym_p_3, mym_p_4])
mym_pl = np.interp(lx/a, [3,4],[mym_pl_3, mym_pl_4])
mxe_p = np.interp(lx/a, [3,4],[mxe_p_3, mxe_p_4])
mxe_pl = np.interp(lx/a, [3,4],[mxe_pl_3, mxe_pl_4])

# %% [markdown]
# <table class="tg">
#   <tr>
#     <th class="tg-baqh" colspan="10">Carga das rodas - 1 tf</th>
#     <th class="tg-baqh" colspan="6">Carga multidão - 1tf/m2</th>
#   </tr>
#   <tr>
#     <td class="tg-baqh" rowspan="3">lx/a</td>
#     <td class="tg-baqh" colspan="3">$M_{xm}$</td>
#     <td class="tg-baqh" colspan="3">$M_{ym}$</td>
#     <td class="tg-baqh" colspan="3">$-M_{xe}$</td>
#     <td class="tg-baqh" colspan="2">$M_{xm}$</td>
#     <td class="tg-baqh" colspan="2">$M_{ym}$</td>
#     <td class="tg-baqh" colspan="2">$-M_{xe}$</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh" colspan="3">$\frac{t}{a}$</td>
#     <td class="tg-baqh" colspan="3">$\frac{t}{a}$</td>
#     <td class="tg-baqh" colspan="3">$\frac{t}{a}$</td>
#     <td class="tg-baqh" rowspan="2">p</td>
#     <td class="tg-baqh" rowspan="2">p'</td>
#     <td class="tg-baqh" rowspan="2">p</td>
#     <td class="tg-baqh" rowspan="2">p'</td>
#     <td class="tg-baqh" rowspan="2">p</td>
#     <td class="tg-baqh" rowspan="2">p'</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">0.5</td>
#     <td class="tg-baqh">{{t_a}}</td>
#     <td class="tg-baqh">1</td>
#     <td class="tg-baqh">0.5</td>
#     <td class="tg-baqh">{{t_a}}</td>
#     <td class="tg-baqh">1</td>
#     <td class="tg-baqh">0.5</td>
#     <td class="tg-baqh">{{t_a}}</td>
#     <td class="tg-baqh">1</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">3</td>
#     <td class="tg-baqh">{{mxm_3_05}}</td>
#     <td class="tg-baqh">{{mxm_ta_3}}</td>
#     <td class="tg-baqh">{{mxm_3_1}}</td>
#     <td class="tg-baqh">{{mym_3_05}}</td>
#     <td class="tg-baqh">{{mym_ta_3}}</td>
#     <td class="tg-baqh">{{mym_3_1}}</td>
#     <td class="tg-baqh">{{mxe_3_05}}</td>
#     <td class="tg-baqh">{{mxe_ta_3}}</td>
#     <td class="tg-baqh">{{mxe_3_1}}</td>
#     <td class="tg-baqh">{{mxm_p_3}}</td>
#     <td class="tg-baqh">{{mxm_pl_3}}</td>
#     <td class="tg-baqh">{{mym_p_3}}</td>
#     <td class="tg-baqh">{{mym_pl_3}}</td>
#     <td class="tg-baqh">{{mxe_p_3}}</td>
#     <td class="tg-baqh">{{mxe_pl_3}}</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">{{lx/a}}</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">{{mxm_m}}</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">{{mym_m}}</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">{{mxe_m}}</td>
#     <td class="tg-baqh"></td>
#     <td class="tg-baqh">{{mxm_p}}</td>
#     <td class="tg-baqh">{{mxm_pl}}</td>
#     <td class="tg-baqh">{{mym_p}}</td>
#     <td class="tg-baqh">{{mym_pl}}</td>
#     <td class="tg-baqh">{{mxe_p}}</td>
#     <td class="tg-baqh">{{mxe_pl}}</td>
#   </tr>
#   <tr>
#     <td class="tg-baqh">4</td>
#     <td class="tg-baqh">{{mxm_4_05}}</td>
#     <td class="tg-baqh">{{mxm_ta_4}}</td>
#     <td class="tg-baqh">{{mxm_4_1}}</td>
#     <td class="tg-baqh">{{mym_4_05}}</td>
#     <td class="tg-baqh">{{mym_ta_4}}</td>
#     <td class="tg-baqh">{{mym_4_1}}</td>
#     <td class="tg-baqh">{{mxe_4_05}}</td>
#     <td class="tg-baqh">{{mxe_ta_4}}</td>
#     <td class="tg-baqh">{{mxe_4_1}}</td>
#     <td class="tg-baqh">{{mxm_p_4}}</td>
#     <td class="tg-baqh">{{mxm_pl_4}}</td>
#     <td class="tg-baqh">{{mym_p_4}}</td>
#     <td class="tg-baqh">{{mym_pl_4}}</td>
#     <td class="tg-baqh">{{mxe_p_4}}</td>
#     <td class="tg-baqh">{{mxe_pl_4}}</td>
#   </tr>
# </table>

# %%
# Determinar os momentos moveis com uso da tabela
peso_roda = 7.5 #tf
peso_multidao_lateral = 0.5 # tf/m2 
peso_multidao_frontal = 0.5  # tf/m2 

mxm_movel = mxm_m*peso_roda + mxm_p*peso_multidao_lateral + mxm_pl*peso_multidao_frontal
mym_movel = mym_m*peso_roda + mym_p*peso_multidao_lateral + mym_pl*peso_multidao_frontal
mxe_movel = mxe_m*peso_roda + mxe_p*peso_multidao_lateral + mxe_pl*peso_multidao_frontal

df_q = pd.DataFrame(index=['Momentos permanentes tf*m/m', 'Momentos móveis tf*m/m'])
df_q['$M_{xm}$'] = [mxm, mxm_movel]
df_q['$M_{ym}$'] = [mym, mym_movel]
df_q['$M_{xe}$'] = [mxe, -mxe_movel]
df_q
# Out:
#                              $M_{xm}$  $M_{ym}$  $M_{xe}$
# Momentos permanentes tf*m/m  1.693896  0.280285 -3.383729
# Momentos móveis tf*m/m       3.681875  1.755000 -7.631250

# %% [markdown]
# ### Diagramas de momentos fletores

# %%
## coeficientes do polinomio para construir diagrama do momento devido cargas permanentes
reacao_de_apoio = g*lx/2
coef_a = -g/2
coef_b = reacao_de_apoio
coef_c = mxe

def dmf_permanente(x):
    return coef_a*np.power(x,2) + coef_b*x + coef_c
    
def dmf_movel_pos(x):
    if(x < 0.3 * lx):
        return mxm_movel * (x / (0.3 * lx))
    elif(x >= 0.7 * lx):
        return mxm_movel * ((lx-x)/(lx-0.7*lx))
    else:
        return mxm_movel
    
def dmf_movel_neg(x):
    if(x < 0.35 * lx):
        return -mxe_movel * (1 - (x/ (0.35*lx)))
    elif(x > 0.65 * lx):
        return -mxe_movel * ((-0.65*lx + x) / (0.35*lx))
    else:
        return 0

# criar espacamentos
espacamento = np.linspace(0, lx, num=400, endpoint=True)
y_p = dmf_permanente(espacamento)
y_m_pos = []
y_m_neg = []

for i in (espacamento):
    y_m_pos.append(dmf_movel_pos(i))
    y_m_neg.append(dmf_movel_neg(i))

# %% [markdown]
# ### Seção transversal

# %% [markdown]
# - a = meio da viga
# - b = comeco da misula
# - c = fim da misula
# - d = Mcarga permamente = 0 (1.4.3)
# - e = Mcarga movel = 0
# - f = Comeco do momento max movel
# - g = meio da laje

# %%
# adotando a seguinte geometria
bw = 0.45 # largura da viga
misula = 0.8 # comprimento da misula

# achar onde momento permanente eh nulo
polinomio = np.poly1d([coef_a, coef_b, coef_c])
x_momento_perm_nulo = np.amin(polinomio.r)

# %%
secoes = ['a', 'b', 'c', 'd', 'e', 'f','g']
coordenadas_secoes = [0, bw/2, bw/2 + misula, x_momento_perm_nulo, 0.3*lx, 0.35*lx, lx/2]
porque_secoes = ['0 (meio do pilar)', 'bw/2 (fim do pilar)', 'bw/2 + m (fim da misula)', 'x (momento permamente nulo)', '0.3 lx (momento movel positivo nulo)' , '0.35 lx (momento movel negativo nulo)',
                 'lx/2 (meio do vao_central)']
df_geo = pd.DataFrame()
df_geo['secoes'] = secoes
df_geo['x'] = coordenadas_secoes
df_geo['def'] = porque_secoes
df_geo
# Out:
#   secoes         x                                    def
# 0      a  0.000000                      0 (meio do pilar)
# 1      b  0.225000                    bw/2 (fim do pilar)
# 2      c  1.025000               bw/2 + m (fim da misula)
# 3      d  1.478466            x (momento permamente nulo)
# 4      e  2.100000   0.3 lx (momento movel positivo nulo)
# 5      f  2.450000  0.35 lx (momento movel negativo nulo)
# 6      g  3.500000             lx/2 (meio do vao_central)

# %%
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)

# plotar dmf permanente
dmf_mg = go.Scatter(
  x=espacamento,
  y=dmf_permanente(espacamento),
    mode= 'lines',
    name = 'Mg'
)

# plotar dmf movel
dmf_m_pos = go.Scatter(
  x=espacamento,
  y= y_m_pos,
    mode= 'lines',
    name = 'Mq pos'
)

dmf_m_neg = go.Scatter(
  x=espacamento,
  y= y_m_neg,
    mode= 'lines',
    name = 'Mq neg'
)

data = go.Data([dmf_mg, dmf_m_pos, dmf_m_neg])

secoes_xaxis = go.XAxis(
    title = 'x (metros)',
    tickmode='array',
    tickvals=coordenadas_secoes,
    ticktext=secoes,
    ticks='outside',
    gridwidth=3,
    range=[0,lx/2]
)

layout = dict(title = 'Diagrama dos momentos fletores',
              xaxis = secoes_xaxis,
              yaxis = dict(
                  title = 'Momento (kN m)',
                  autorange='reversed'
              ),
              shapes= [
                  # laje
                    {
                        'type': 'line',
                        'xref': 'x',
                        'yref': 'y',
                        'x0': 0,
                        'y0': 0,
                        'x1': lx,
                        'y1': 0,
                        'line': {
                            'color': 'rgba(127, 128, 118,0.3)',
                            'width': 20
                        }
                    }
              ])

fig = dict(data=data, layout=layout)
py.iplot(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="752ea8da-3c1d-40b7-bd78-ef01c1c546e9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("752ea8da-3c1d-40b7-bd78-ef01c1c546e9", [{"type": "scatter", "x": [0.0, 0.017543859649122806, 0.03508771929824561, 0.05263157894736842, 0.07017543859649122, 0.08771929824561403, 0.10526315789473684, 0.12280701754385964, 0.14035087719298245, 0.15789473684210525, 0.17543859649122806, 0.19298245614035087, 0.21052631578947367, 0.22807017543859648, 0.24561403508771928, 0.2631578947368421, 0.2807017543859649, 0.2982456140350877, 0.3157894736842105, 0.3333333333333333, 0.3508771929824561, 0.3684210526315789, 0.38596491228070173, 0.40350877192982454, 0.42105263157894735, 0.43859649122807015, 0.45614035087719296, 0.47368421052631576, 0.49122807017543857, 0.5087719298245614, 0.5263157894736842, 0.5438596491228069, 0.5614035087719298, 0.5789473684210527, 0.5964912280701754, 0.6140350877192982, 0.631578947368421, 0.6491228070175439, 0.6666666666666666, 0.6842105263157894, 0.7017543859649122, 0.7192982456140351, 0.7368421052631579, 0.7543859649122806, 0.7719298245614035, 0.7894736842105263, 0.8070175438596491, 0.8245614035087718, 0.8421052631578947, 0.8596491228070176, 0.8771929824561403, 0.894736842105263, 0.9122807017543859, 0.9298245614035088, 0.9473684210526315, 0.9649122807017543, 0.9824561403508771, 1.0, 1.0175438596491229, 1.0350877192982455, 1.0526315789473684, 1.0701754385964912, 1.0877192982456139, 1.1052631578947367, 1.1228070175438596, 1.1403508771929824, 1.1578947368421053, 1.175438596491228, 1.1929824561403508, 1.2105263157894737, 1.2280701754385963, 1.2456140350877192, 1.263157894736842, 1.280701754385965, 1.2982456140350878, 1.3157894736842104, 1.3333333333333333, 1.3508771929824561, 1.3684210526315788, 1.3859649122807016, 1.4035087719298245, 1.4210526315789473, 1.4385964912280702, 1.4561403508771928, 1.4736842105263157, 1.4912280701754386, 1.5087719298245612, 1.526315789473684, 1.543859649122807, 1.5614035087719298, 1.5789473684210527, 1.5964912280701753, 1.6140350877192982, 1.631578947368421, 1.6491228070175437, 1.6666666666666665, 1.6842105263157894, 1.7017543859649122, 1.719298245614035, 1.7368421052631577, 1.7543859649122806, 1.7719298245614035, 1.789473684210526, 1.807017543859649, 1.8245614035087718, 1.8421052631578947, 1.8596491228070176, 1.8771929824561402, 1.894736842105263, 1.912280701754386, 1.9298245614035086, 1.9473684210526314, 1.9649122807017543, 1.9824561403508771, 2.0, 2.017543859649123, 2.0350877192982457, 2.052631578947368, 2.070175438596491, 2.087719298245614, 2.1052631578947367, 2.1228070175438596, 2.1403508771929824, 2.1578947368421053, 2.1754385964912277, 2.1929824561403506, 2.2105263157894735, 2.2280701754385963, 2.245614035087719, 2.263157894736842, 2.280701754385965, 2.2982456140350878, 2.3157894736842106, 2.333333333333333, 2.350877192982456, 2.3684210526315788, 2.3859649122807016, 2.4035087719298245, 2.4210526315789473, 2.43859649122807, 2.4561403508771926, 2.4736842105263155, 2.4912280701754383, 2.508771929824561, 2.526315789473684, 2.543859649122807, 2.56140350877193, 2.5789473684210527, 2.5964912280701755, 2.614035087719298, 2.631578947368421, 2.6491228070175437, 2.6666666666666665, 2.6842105263157894, 2.7017543859649122, 2.719298245614035, 2.7368421052631575, 2.7543859649122804, 2.7719298245614032, 2.789473684210526, 2.807017543859649, 2.824561403508772, 2.8421052631578947, 2.8596491228070176, 2.8771929824561404, 2.894736842105263, 2.9122807017543857, 2.9298245614035086, 2.9473684210526314, 2.9649122807017543, 2.982456140350877, 3.0, 3.0175438596491224, 3.0350877192982453, 3.052631578947368, 3.070175438596491, 3.087719298245614, 3.1052631578947367, 3.1228070175438596, 3.1403508771929824, 3.1578947368421053, 3.1754385964912277, 3.1929824561403506, 3.2105263157894735, 3.2280701754385963, 3.245614035087719, 3.2631578 ...

# %% [markdown]
# ### Momentos fletores nas seções de cálculo devido a carga permanente

# %%
mg = []
for i in coordenadas_secoes:
    mg.append(dmf_permanente(i))
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df['Mg'] = mg
df
# Out:
#   Secao     x (m)        Mg
# 0     a  0.000000 -3.383729
# 1     b  0.225000 -2.751876
# 2     c  1.025000 -0.845176
# 3     d  1.478466  0.000000
# 4     e  2.100000  0.881476
# 5     f  2.450000  1.236909
# 6     g  3.500000  1.693896

# %% [markdown]
# ### Momento fletor na seção de cálculo, devido carga móvel

# %%
# definir funcao do momento fletor devido carga movel positiva
def ms_movel_neg(x):
    if(x <= 0.35*lx):
        return (mxe_movel*((0.35*lx - x)/(0.35*lx)))
    else: 
        return 0
    
# definir funcao do momento fletor devido carga movel negativa
def ms_movel_pos(x):
    if(x <= 0.30*lx):
        return mxm_movel* ((x)/ (0.3*lx))
    else: return mxm_movel

# %%
mq_neg = []
mq_pos = []
for i in coordenadas_secoes:
    mq_neg.append(-ms_movel_neg(i))
    mq_pos.append(ms_movel_pos(i))
    
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df['Mq (+)'] = mq_pos
df['Mq (-)'] = mq_neg
df
# Out:
#   Secao     x (m)    Mq (+)    Mq (-)
# 0     a  0.000000  0.000000 -7.631250
# 1     b  0.225000  0.394487 -6.930421
# 2     c  1.025000  1.797106 -4.438584
# 3     d  1.478466  2.592156 -3.026130
# 4     e  2.100000  3.681875 -1.090179
# 5     f  2.450000  3.681875 -0.000000
# 6     g  3.500000  3.681875  0.000000

# %% [markdown]
# ### Coeficiente de impacto vertical

# %% [markdown]
# Quanto **menor** o vão, **mais** impacto vertical

# %%
# para l < 10 metros usa-se
if(lx < 10):
    civ = 1.35
# Numero de faixas de trafego
n = 2

# coeficiente de numero de faixas deve ser > 0.9
cnf = 1 - 0.05*(n-2)

# coeficiente de amplificacao
psi = civ * cnf

print(' lx = {} \n civ = {} \n cnf = {} \n fator de amplificacao = {}'.format(lx, civ, cnf, psi))
# Out:
#  lx = 7
#  civ = 1.35
#  cnf = 1.0
#  fator de amplificacao = 1.35

# %% [markdown]
# ### Envoltório momento fletor

# %%
# momentos amplificados
mq_neg_amp = np.multiply(mq_neg,1.35)
mq_pos_amp = np.multiply(mq_pos,1.35)

# envoltorias
env_max = mg + mq_pos_amp
env_min = mg + mq_neg_amp

# tabela
secoes = ['a', 'b', 'c', 'd', 'e', 'f','g']
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df['Mg'] = mg
df['Mq pos amplificado'] = mq_pos_amp
df['Mq neg amplificado'] = mq_neg_amp
df['Envoltoria max'] = env_max
df['Envoltoria min'] = env_min
df
# Out:
#   Secao     x (m)        Mg  Mq pos amplificado  Mq neg amplificado  \
# 0     a  0.000000 -3.383729            0.000000          -10.302188
# 1     b  0.225000 -2.751876            0.532557           -9.356068
# 2     c  1.025000 -0.845176            2.426093           -5.992089
# 3     d  1.478466  0.000000            3.499410           -4.085276
# 4     e  2.100000  0.881476            4.970531           -1.471741
# 5     f  2.450000  1.236909            4.970531           -0.000000
# 6     g  3.500000  1.693896            4.970531            0.000000
#
#    Envoltoria max  Envoltoria min
# 0       -3.383729      -13.685917
# 1       -2.219319      -12.107944
# 2        1.580917       -6.837265
# 3        3.499410       -4.085276
# 4        5.852007       -0.590265
# 5        6.207441        1.236909
# 6        6.664427        1.693896

# %%
dmf_mg2 = go.Scatter(
  x=coordenadas_secoes,
  y=df['Mg'],
    mode= 'lines',
    name = 'Mg'
)
dmf_mq_pos_amp = go.Scatter(
  x=coordenadas_secoes,
  y=df['Mq pos amplificado'],
    mode= 'lines',
    name = 'Mq pos amp'
)

dmf_mq_neg_amp = go.Scatter(
  x=coordenadas_secoes,
  y=df['Mq neg amplificado'],
    mode= 'lines',
    name = 'Mq neg amp'
)

dmf_mq_env_max = go.Scatter(
  x=coordenadas_secoes,
  y=df['Envoltoria max'],
    mode= 'lines+markers',
    name = 'Mg + Mq pos amp'
)

dmf_mq_env_min = go.Scatter(
  x=coordenadas_secoes,
  y=df['Envoltoria min'],
    mode= 'lines+markers',
    name = 'Mg + Mq neg amp'
)

data2 = go.Data([dmf_mg2, dmf_mq_pos_amp, dmf_mq_neg_amp,dmf_mq_env_max,dmf_mq_env_min])

fig2 = dict(data=data2, layout=layout)
py.iplot(fig2)
# Out:
# <div id="5456e924-33cc-452e-ac2d-6808edd22c38" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5456e924-33cc-452e-ac2d-6808edd22c38", [{"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-3.3837292999999997, -2.7518758624999995, -0.8451758624999992, 0.0, 0.8814757000000011, 1.2369094499999997, 1.6938957000000014], "mode": "lines", "name": "Mg"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [0.0, 0.5325569196428571, 2.4260926339285716, 3.499410048770317, 4.97053125, 4.97053125, 4.97053125], "mode": "lines", "name": "Mq pos amp"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-10.302187500000002, -9.356068239795919, -5.992088647959183, -4.085275984300181, -1.4717410714285704, -0.0, 0.0], "mode": "lines", "name": "Mq neg amp"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-3.3837292999999997, -2.2193189428571425, 1.5809167714285723, 3.499410048770317, 5.852006950000001, 6.207440699999999, 6.664426950000001], "mode": "lines+markers", "name": "Mg + Mq pos amp"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-13.685916800000001, -12.107944102295917, -6.837264510459182, -4.085275984300181, -0.5902653714285693, 1.2369094499999997, 1.6938957000000014], "mode": "lines+markers", "name": "Mg + Mq neg amp"}], {"title": "Diagrama dos momentos fletores", "xaxis": {"title": "x (metros)", "tickmode": "array", "tickvals": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "ticktext": ["a", "b", "c", "d", "e", "f", "g"], "ticks": "outside", "gridwidth": 3, "range": [0, 3.5]}, "yaxis": {"title": "Momento (kN m)", "autorange": "reversed"}, "shapes": [{"type": "line", "xref": "x", "yref": "y", "x0": 0, "y0": 0, "x1": 7, "y1": 0, "line": {"color": "rgba(127, 128, 118,0.3)", "width": 20}}]}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### DImensionamento ao momento fletor

# %%
#fck 25
fck = 4 # kN/cm2 
fcd = fck/1.35
#Aco CA 50
fyk = 50  #kN/cm2
fs = fyk/1.15

# %%
# formulas

## KMD
def KMD(md,bw,d,fcd):
    return (md*1000)/(bw * d**2 * fcd)

## Area de Aco
def AS(md,kz,d,fs):
    return ((md)* 1000)/(kz*d*fs)

## Acha o kx
def find_kx(md):
    kx1, kx2 = np.roots([-.0272, 0.68, -md])
    if(kx1 > 0 and kx1< 1):
        return kx1
    else:
        return kx2

## funcao completa
## Acha area de aco a partir do md e geometria    
def md_to_as(md_,bw,d,h,fcd,fs):
    """
    returns: kmd, kx, kz, as_prov, as_min, as_def"""
    md = np.abs(md_)
    kmd_ = KMD(md,bw,d,fcd)
    kx_ = find_kx(kmd_)
    kz_ = 1-(0.4*kx_)
    as_prov = AS(np.abs(md), kz_, d, fs)
    as_def = as_prov
    as_min = 0.0015 * bw * h
    if(as_prov < as_min):
        as_def = as_min
    return(kmd_, kx_, kz_, as_prov, as_min, as_def)

# %%
# momentos com coeficiente de seguranca
mg_coef = np.multiply(mg, 1.35) #momento permanente
mq_pos_coef = np.multiply(mq_pos_amp, 1.5) #momento acidental POSITIVO
mq_neg_coef = np.multiply(mq_neg_amp, 1.5) #momento acidental NEGATIVO

#MD positivo e negativo
md_pos = (mg_coef + mq_pos_coef)
md_neg = (mg_coef + mq_neg_coef)

# geometria 
## Altura aumenta ao chegar proximo ao apoio
bw = 100
d = [35,32,22,22,22,22,22]
h = [38,35,25,25,25,25,25]

df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df['Mg'] = mg
df['Mq (+)'] = mq_pos_amp
df['MD'] = md_pos
df['bw (cm)'] = bw
df['d (cm)'] = d
df['h (cm)'] = h
df
# Out:
#   Secao     x (m)        Mg    Mq (+)        MD  bw (cm)  d (cm)  h (cm)
# 0     a  0.000000 -3.383729  0.000000 -4.568035      100      35      38
# 1     b  0.225000 -2.751876  0.532557 -2.916197      100      32      35
# 2     c  1.025000 -0.845176  2.426093  2.498152      100      22      25
# 3     d  1.478466  0.000000  3.499410  5.249115      100      22      25
# 4     e  2.100000  0.881476  4.970531  8.645789      100      22      25
# 5     f  2.450000  1.236909  4.970531  9.125625      100      22      25
# 6     g  3.500000  1.693896  4.970531  9.742556      100      22      25

# %% [markdown]
# #### Momentos positivos

# %%
# aplicar formula 'md_to_as' que retorna kmd, kx, kz, area de aco prov, area minima, e area definitiva
# a formula tem como parametro o MD, bw, d, h, fcd, fs
df2= pd.DataFrame(columns=('kmd', 'kx', 'kz', 'as_prov','as_min', 'as_def'))
for i in range(0, len(d)):
    df2.loc[i] = (md_to_as(md_pos[i],bw,d[i],h[i],fcd,fs))

# concatenar a tabela anterior com o resultado obtido    
df_pos = pd.concat([df,df2], axis=1)
df_pos[2:]
# Out:
#   Secao     x (m)        Mg    Mq (+)        MD  bw (cm)  d (cm)  h (cm)  \
# 2     c  1.025000 -0.845176  2.426093  2.498152      100      22      25
# 3     d  1.478466  0.000000  3.499410  5.249115      100      22      25
# 4     e  2.100000  0.881476  4.970531  8.645789      100      22      25
# 5     f  2.450000  1.236909  4.970531  9.125625      100      22      25
# 6     g  3.500000  1.693896  4.970531  9.742556      100      22      25
#
#         kmd        kx        kz    as_prov  as_min     as_def
# 2  0.017420  0.025644  0.989742   2.638771    3.75   3.750000
# 3  0.036603  0.053944  0.978422   5.608734    3.75   5.608734
# 4  0.060288  0.088976  0.964410   9.372345    3.75   9.372345
# 5  0.063634  0.093933  0.962427   9.912883    3.75   9.912883
# 6  0.067936  0.100309  0.959877  10.611156    3.75  10.611156

# %% [markdown]
# #### Momentos negativos

# %%
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df['Mg'] = mg
df['Mq pos'] = mq_neg_amp
df['MD'] = md_neg
df['bw (cm)'] = bw
df['d (cm)'] = d
df['h (cm)'] = h
df
# aplicar formula 'md_to_as' que retorna kmd, kx, kz, area de aco prov, area minima, e area definitiva
# a formula tem como parametro o MD, bw, d, h, fcd, fs
df2= pd.DataFrame(columns=('kmd', 'kx', 'kz', 'as_prov','as_min', 'as_def'))
for i in range(0, len(secoes)):
    df2.loc[i] = (md_to_as(md_neg[i],bw,d[i],h[i],fcd,fs))

# concatenar a tabela anterior com o resultado obtido    
df_neg = pd.concat([df,df2], axis=1)
df_neg[:-2]
# Out:
#   Secao     x (m)        Mg     Mq pos         MD  bw (cm)  d (cm)  h (cm)  \
# 0     a  0.000000 -3.383729 -10.302188 -20.021316      100      35      38
# 1     b  0.225000 -2.751876  -9.356068 -17.749135      100      32      35
# 2     c  1.025000 -0.845176  -5.992089 -10.129120      100      22      25
# 3     d  1.478466  0.000000  -4.085276  -6.127914      100      22      25
# 4     e  2.100000  0.881476  -1.471741  -1.017619      100      22      25
#
#         kmd        kx        kz    as_prov  as_min     as_def
# 0  0.055161  0.081384  0.967447  13.599578    5.70  13.599578
# 1  0.058499  0.086327  0.965469  13.213460    5.25  13.213460
# 2  0.070632  0.104305  0.958278  11.050590    3.75  11.050590
# 3  0.042731  0.062998  0.974801   6.572067    3.75   6.572067
# 4  0.007096  0.010440  0.995824   1.068336    3.75   3.750000

# %% [markdown]
# #### Momento positivos - Verificação fadiga

# %%
# Formulas

## Momento de inercia
def find_i(bw, x, AS, alfa_e, d):
    return ((bw*(x**3)/3) + (AS*alfa_e)* ((d-x)**2))

## Tensao concreto
def tensao_concreto(m, I, y):
    return ((m/I) * y)

## Tensao aco
def tensao_aco(alfa_e, m, I, d, x):
    return ((m/I) * (d-x) * alfa_e) * 1000

## Tensao aco negativa
def tensao_aco_neg(alfa_e, m, I, c, x):
    return ((m/I) * (x-c) * alfa_e) * -1000

def find_x(bw,alfa_e,AS,d):
    # a*x^2 + b*x + c = 0
    a = (bw/2)
    b = alfa_e * AS
    c = -alfa_e * AS * d
    x1, x2 = np.roots([a,b,c])
    if(x1 > x2):
#         print(x1)
        return x1
    else:
#         print(x2)
        return x2

# %%
# coeficiente de transformacao aco -> concreto (nbr 6118:2014, 23.5.3)
alfa_e = 10

# coeficiente de reducao para TABULEIRO
psi_1 = 0.8
        
#Md de servico = mg + mq(amp) * psi_1
md_ser_pos = mg + np.multiply(mq_pos_amp, psi_1)

# Tabela momentos e geometria
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df['Mg'] = mg
df['Mq pos'] = mq_pos_amp
df['MD serv'] = md_ser_pos
df['bw (cm)'] = bw
df['d (cm)'] = d
df['h (cm)'] = h
df
# aplicar formula 'md_to_as' que retorna kmd, kx, kz, area de aco prov, area minima, e area definitiva
# a formula tem como parametro o MD, bw, d, h, fcd, fs
df2= pd.DataFrame(columns=('kmd', 'kx', 'kz', 'as_prov','as_min', 'as_def'))
for i in range(0, len(d)):
    # LEMBRANDO QUE PARA AREA DE ACO USAR MD e NAO MD DE SERVICO!!!!
    df2.loc[i] = (md_to_as(md_pos[i],bw,d[i],h[i],fcd,fs))

# concatenar a tabela anterior com o resultado obtido    
df_pos_ser = pd.concat([df,df2], axis=1)

# Achar X
x_pos = []
for i in range(0, len(md_ser_pos)):
    x_pos.append(find_x(bw, alfa_e, df_pos['as_def'][i], d[i]))
    
# Achar momento de inercia 2
i_pos = []
for i in range(0, len(md_ser_pos)):
    i_pos.append(find_i(bw, x_pos[i], df_pos_ser['as_def'][i],alfa_e, d[i]))
    
# Achar tensao armadura positiva
## tensao inf
tensao_as_inf = []
for i in range(0, len(md_ser_pos)):
    tensao_as_inf.append(tensao_aco(alfa_e, md_ser_pos[i],i_pos[i],d[i], x_pos[i]))
    
## tensao mg (apenas carga permanente)
tensao_as_inf_mg = []
for i in range(0, len(md_ser_pos)):
    result = tensao_aco(alfa_e, mg[i],i_pos[i],d[i], x_pos[i])
    # condicao para guardar apenas resultados acima de 0
    if(result >= 0):
        tensao_as_inf_mg.append(result)
    else:
        tensao_as_inf_mg.append(0)

# Achar tensao armadura negativa
tensao_as_sup = []
for i in range(0, len(md_ser_pos)):
    tensao_as_sup.append(tensao_aco_neg(alfa_e, md_ser_pos[i],i_pos[i],3, x_pos[i]))

df_pos_ser['x'] = x_pos
df_pos_ser['I'] = i_pos  
df_pos_ser['Tensao as inf mom_pos'] = tensao_as_inf
df_pos_ser['Tensao as inf mg'] = tensao_as_inf_mg
df_pos_ser['Tensao as sup mom_pos'] = tensao_as_sup

df_pos_ser[2:]
# Out:
#   Secao     x (m)        Mg    Mq pos   MD serv  bw (cm)  d (cm)  h (cm)  \
# 2     c  1.025000 -0.845176  2.426093  1.095698      100      22      25
# 3     d  1.478466  0.000000  3.499410  2.799528      100      22      25
# 4     e  2.100000  0.881476  4.970531  4.857901      100      22      25
# 5     f  2.450000  1.236909  4.970531  5.213334      100      22      25
# 6     g  3.500000  1.693896  4.970531  5.670321      100      22      25
#
#         kmd        kx        kz    as_prov  as_min     as_def         x  \
# 2  0.017420  0.025644  0.989742   2.638771    3.75   3.750000  3.704292
# 3  0.036603  0.053944  0.978422   5.608734    3.75   5.608734  4.438428
# 4  0.060288  0.088976  0.964410   9.372345    3.75   9.372345  5.552506
# 5  0.063634  0.093933  0.962427   9.912883    3.75   9.912883  5.686985
# 6  0.067936  0.100309  0.959877  10.611156    3.75  10.611156  5.853727
#
#               I  Tensao as inf mom_pos  Tensao as inf mg  \
# 2  14246.800821              14.070931          0.000000
# 3  20212.345995              24.323804          0.000000
# 4  31060.257605              25.724286          4.667723
# 5  32510.526830              26.159281          6.206520
# 6  34349.659971              26.653697          7.962263
#
#    Tensao as sup mom_pos
# 2              -0.541660
# 3              -1.992306
# 4              -3.992181
# 5              -4.308805
# 6              -4.710832

# %%
dmf_mg2 = go.Scatter(
  x=coordenadas_secoes,
  y=df['Mg'],
    mode= 'lines',
    name = 'Mg'
)
dmf_mq_pos = go.Scatter(
  x=coordenadas_secoes,
  y=df['Mq pos'],
    mode= 'lines',
    name = 'Mq pos'
)

dmf_md_ser = go.Scatter(
  x=coordenadas_secoes,
  y=df['MD serv'],
    mode= 'lines+markers',
    name = 'MD serv'
)

data3 = go.Data([dmf_mg2, dmf_mq_pos, dmf_md_ser])

fig3 = dict(data=data3, layout=layout)
py.iplot(fig3)
# Out:
# <div id="1a3eff0c-1a08-406d-a66b-d5845a93dccf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1a3eff0c-1a08-406d-a66b-d5845a93dccf", [{"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-3.3837292999999997, -2.7518758624999995, -0.8451758624999992, 0.0, 0.8814757000000011, 1.2369094499999997, 1.6938957000000014], "mode": "lines", "name": "Mg"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [0.0, 0.5325569196428571, 2.4260926339285716, 3.499410048770317, 4.97053125, 4.97053125, 4.97053125], "mode": "lines", "name": "Mq pos"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-3.3837292999999997, -2.325830326785714, 1.095698244642858, 2.799528039016254, 4.857900700000001, 5.21333445, 5.670320700000001], "mode": "lines+markers", "name": "MD serv"}], {"title": "Diagrama dos momentos fletores", "xaxis": {"title": "x (metros)", "tickmode": "array", "tickvals": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "ticktext": ["a", "b", "c", "d", "e", "f", "g"], "ticks": "outside", "gridwidth": 3, "range": [0, 3.5]}, "yaxis": {"title": "Momento (kN m)", "autorange": "reversed"}, "shapes": [{"type": "line", "xref": "x", "yref": "y", "x0": 0, "y0": 0, "x1": 7, "y1": 0, "line": {"color": "rgba(127, 128, 118,0.3)", "width": 20}}]}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# #### Momentos negativos - Verificação fadiga

# %%
#Md de servico = mg + mq(amp) * psi_1
md_ser_neg = mg + np.multiply(mq_neg_amp, psi_1)

# Tabela momentos e geometria
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df['Mg'] = mg
df['Mq pos'] = mq_neg_amp
df['MD serv'] = md_ser_neg
df['bw (cm)'] = bw
df['d (cm)'] = d
df['h (cm)'] = h
df
# aplicar formula 'md_to_as' que retorna kmd, kx, kz, area de aco prov, area minima, e area definitiva
# a formula tem como parametro o MD, bw, d, h, fcd, fs
df2= pd.DataFrame(columns=('kmd', 'kx', 'kz', 'as_prov','as_min', 'as_def'))
for i in range(0, len(d)):
   # LEMBRANDO QUE PARA AREA DE ACO USAR MD e NAO MD DE SERVICO!!!!
    df2.loc[i] = (md_to_as(md_neg[i],bw,d[i],h[i],fcd,fs))

# concatenar a tabela anterior com o resultado obtido    
df_neg_ser = pd.concat([df,df2], axis=1)

# Achar X
x_pos = []
for i in range(0, len(md_ser_neg)):
    x_pos.append(find_x(bw, alfa_e, df_neg['as_def'][i], d[i]))
    
# Achar momento de inercia 2
i_pos = []
for i in range(0, len(md_ser_neg)):
    i_pos.append(find_i(bw, x_pos[i], df_neg_ser['as_def'][i],alfa_e, d[i]))
    
# Achar tensao armadura positiva - TENSAO USAR MD DE SERVICO
## tensao inf
tensao_as_inf = []
for i in range(0, len(md_ser_pos)):
    tensao_as_inf.append(tensao_aco(alfa_e, -md_ser_neg[i],i_pos[i],d[i], x_pos[i]))

## tensao mg (apenas carga permanente)
tensao_as_mg = []
for i in range(0, len(md_ser_pos)):
    result = tensao_aco(alfa_e, -mg[i],i_pos[i],d[i], x_pos[i])
    # condicao para guardar apenas resultados acima de 0
    if(result >= 0):
        tensao_as_mg.append(result)
    else:
        tensao_as_mg.append(0)

# Achar tensao armadura negativa
tensao_as_sup = []
for i in range(0, len(md_ser_pos)):
    result = tensao_aco_neg(alfa_e, -md_ser_neg[i],i_pos[i],3, x_pos[i])
    ## armazenar apenas valores negativos
    if(result < 0):
        tensao_as_sup.append(result)
    else:
        tensao_as_sup.append(0)

df_neg_ser['x'] = x_pos
df_neg_ser['I'] = i_pos
df_neg_ser['Tensao as inf mom_neg'] = tensao_as_inf
df_neg_ser['Tensao as mg'] = tensao_as_mg
df_neg_ser['Tensao as sup mom_neg'] = tensao_as_sup

df_neg_ser[:-2]
# Out:
#   Secao     x (m)        Mg     Mq pos    MD serv  bw (cm)  d (cm)  h (cm)  \
# 0     a  0.000000 -3.383729 -10.302188 -11.625479      100      35      38
# 1     b  0.225000 -2.751876  -9.356068 -10.236730      100      32      35
# 2     c  1.025000 -0.845176  -5.992089  -5.638847      100      22      25
# 3     d  1.478466  0.000000  -4.085276  -3.268221      100      22      25
# 4     e  2.100000  0.881476  -1.471741  -0.295917      100      22      25
#
#         kmd        kx        kz    as_prov  as_min     as_def         x  \
# 0  0.055161  0.081384  0.967447  13.599578    5.70  13.599578  8.491262
# 1  0.058499  0.086327  0.965469  13.213460    5.25  13.213460  7.969084
# 2  0.070632  0.104305  0.958278  11.050590    3.75  11.050590  5.954952
# 3  0.042731  0.062998  0.974801   6.572067    3.75   6.572067  4.760266
# 4  0.007096  0.010440  0.995824   1.068336    3.75   3.750000  3.704292
#
#                I  Tensao as inf mom_neg  Tensao as mg  Tensao as sup mom_neg
# 0  115973.796854              26.572967      7.734367              -5.504567
# 1   93175.304542              26.401632      7.097385              -5.459298
# 2   35488.073692              25.494641      3.821252              -4.695245
# 3   23128.345022              24.361127     -0.000000              -2.487398
# 4   14246.800821               3.800161      0.000000              -0.146287

# %%
dmf_mg2 = go.Scatter(
  x=coordenadas_secoes,
  y=df['Mg'],
    mode= 'lines',
    name = 'Mg'
)
dmf_mq_neg = go.Scatter(
  x=coordenadas_secoes,
  y=mq_neg_amp,
    mode= 'lines',
    name = 'Mq pos'
)

dmf_md_ser_neg = go.Scatter(
  x=coordenadas_secoes,
  y=md_ser_neg,
    mode= 'lines+markers',
    name = 'MD serv'
)

data4 = go.Data([dmf_mg2, dmf_mq_neg, dmf_md_ser_neg])

fig4 = dict(data=data4, layout=layout)
py.iplot(fig4)
# Out:
# <div id="2b574374-8588-47db-a78d-30184cc128f9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2b574374-8588-47db-a78d-30184cc128f9", [{"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-3.3837292999999997, -2.7518758624999995, -0.8451758624999992, 0.0, 0.8814757000000011, 1.2369094499999997, 1.6938957000000014], "mode": "lines", "name": "Mg"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-10.302187500000002, -9.356068239795919, -5.992088647959183, -4.085275984300181, -1.4717410714285704, -0.0, 0.0], "mode": "lines", "name": "Mq pos"}, {"type": "scatter", "x": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "y": [-11.625479300000002, -10.236730454336735, -5.638846780867345, -3.268220787440145, -0.29591715714285516, 1.2369094499999997, 1.6938957000000014], "mode": "lines+markers", "name": "MD serv"}], {"title": "Diagrama dos momentos fletores", "xaxis": {"title": "x (metros)", "tickmode": "array", "tickvals": [0, 0.225, 1.0250000000000001, 1.4784659290528885, 2.1, 2.4499999999999997, 3.5], "ticktext": ["a", "b", "c", "d", "e", "f", "g"], "ticks": "outside", "gridwidth": 3, "range": [0, 3.5]}, "yaxis": {"title": "Momento (kN m)", "autorange": "reversed"}, "shapes": [{"type": "line", "xref": "x", "yref": "y", "x0": 0, "y0": 0, "x1": 7, "y1": 0, "line": {"color": "rgba(127, 128, 118,0.3)", "width": 20}}]}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# #### Resumo armadura positiva

# %%
# Tabela momentos e geometria
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df_resumo = pd.concat([
    df,
    df_pos_ser['Tensao as inf mom_pos'],
    df_pos_ser['Tensao as inf mg'],
    df_neg_ser['Tensao as sup mom_neg'],
], axis=1)

# Variacao da tensao na armadura

### QUE VALOR EH ESSE ONDE ARMADURA NEGATTIVA
delta = []
for i in range(0, len(secoes)):
    inf_sup = df_pos_ser['Tensao as inf mom_pos'][i] - df_neg_ser['Tensao as sup mom_neg'][i]
    inf_inf = df_pos_ser['Tensao as inf mom_pos'][i] -  df_pos_ser['Tensao as inf mg'][i]
    # delta apenas para valores negativos de mom negativo, o resto usar mg do momento positivo
    if(df_neg_ser['Tensao as sup mom_neg'][i] > 0):
        delta.append(inf_sup)
    else:
        delta.append(inf_inf)


# k fad
## considerando 2 * 10**6 (2 milhoes) de ciclos
delta_admis = 19 # kN/cm2 -- > 190 MPa
k_fad = []
for i in range(0, len(delta)):
    k_fad.append(delta[i]/delta_admis)

# k * As
k_as = np.multiply(df_pos_ser['as_def'], k_fad)

# Espacamento Armadura adotada
def espacamento(bitola, AS):
    area = np.pi*bitola**2/4
    provisorio = (100 / (AS/area))
    adotado = np.floor(provisorio)
    if(provisorio > 20):
        adotado = 20
    return (provisorio, adotado)

esp_prov = []
esp_adotado = []
bitola = 1.25
for i in range(0, len(delta)):
    esp_prov.append(espacamento(bitola, k_as[i])[0])
    esp_adotado.append(espacamento(bitola, k_as[i])[1])

df_resumo['Variacao tensao as'] = delta
df_resumo['k fad'] = k_fad
df_resumo['As'] = df_pos_ser['as_def']
df_resumo['k * As'] = k_as
df_resumo['esp prov'] = esp_prov
df_resumo['esp adotado'] = esp_adotado
df_resumo['bitola cm'] = bitola
df_resumo[2:]
# Out:
#   Secao     x (m)  Tensao as inf mom_pos  Tensao as inf mg  \
# 2     c  1.025000              14.070931          0.000000
# 3     d  1.478466              24.323804          0.000000
# 4     e  2.100000              25.724286          4.667723
# 5     f  2.450000              26.159281          6.206520
# 6     g  3.500000              26.653697          7.962263
#
#    Tensao as sup mom_neg  Variacao tensao as     k fad         As     k * As  \
# 2              -4.695245           14.070931  0.740575   3.750000   2.777157
# 3              -2.487398           24.323804  1.280200   5.608734   7.180303
# 4              -0.146287           21.056563  1.108240   9.372345  10.386809
# 5               0.000000           19.952762  1.050145   9.912883  10.409968
# 6               0.000000           18.691435  0.983760  10.611156  10.438828
#
#     esp prov  esp adotado  bitola cm
# 2  44.188516         20.0       1.25
# 3  17.090987         17.0       1.25
# 4  11.814838         11.0       1.25
# 5  11.788553         11.0       1.25
# 6  11.755962         11.0       1.25

# %% [markdown]
# #### Resumo armadura negativa

# %%
# Tabela momentos e geometria
df = pd.DataFrame()
df['Secao'] = secoes
df['x (m)'] = coordenadas_secoes
df_resumo_neg = pd.concat([
    df,
    df_neg_ser['Tensao as inf mom_neg'],
    df_pos_ser['Tensao as sup mom_pos'],
    df_neg_ser['Tensao as mg']
], axis=1)

# Variacao da tensao na armadura

## verificar situacao critica
delta = []
for i in range(0, len(mg)):
    if(df_pos_ser['Tensao as sup mom_pos'][i] > 0):
        delta.append(df_neg_ser['Tensao as inf mom_neg'][i] - df_neg_ser['Tensao as mg'][i])
    else:
        delta.append(df_neg_ser['Tensao as inf mom_neg'][i] - df_pos_ser['Tensao as sup mom_pos'][i])


# k fad
## considerando 2 * 10**6 (2 milhoes) de ciclos
delta_admis = 19 # kN/cm2 -- > 190 MPa
k_fad = []
for i in range(0, len(delta)):
    result = delta[i]/delta_admis
    # k fad nao pode ser menor que 1, caso for -> utilizar 1
    if(result < 1) :
        k_fad.append(1)
    else:
        k_fad.append(result)

# k * As
k_as = np.multiply(df_neg_ser['as_def'], k_fad)

# Espacamento Armadura adotada - ARMADURA NEGATIVA BITOLA = 16mm
esp_prov = []
esp_adotado = []
bitola = 1.6
for i in range(0, len(delta)):
    esp_prov.append(espacamento(bitola, k_as[i])[0])
    esp_adotado.append(espacamento(bitola, k_as[i])[1])

df_resumo_neg['Variacao tensao as'] = delta
df_resumo_neg['k fad'] = k_fad
df_resumo_neg['As'] = df_neg_ser['as_def']
df_resumo_neg['k * As'] = k_as
df_resumo_neg['esp prov'] = esp_prov
df_resumo_neg['esp adotado'] = esp_adotado
df_resumo_neg['bitola'] = bitola
df_resumo_neg[:-2]
# Out:
#   Secao     x (m)  Tensao as inf mom_neg  Tensao as sup mom_pos  Tensao as mg  \
# 0     a  0.000000              26.572967               1.702380      7.734367
# 1     b  0.225000              26.401632               1.259381      7.097385
# 2     c  1.025000              25.494641              -0.541660      3.821252
# 3     d  1.478466              24.361127              -1.992306     -0.000000
# 4     e  2.100000               3.800161              -3.992181      0.000000
#
#    Variacao tensao as     k fad         As     k * As   esp prov  esp adotado  \
# 0           18.838599  1.000000  13.599578  13.599578  14.784424         14.0
# 1           19.304247  1.016013  13.213460  13.425047  14.976628         14.0
# 2           26.036301  1.370332  11.050590  15.142972  13.277574         13.0
# 3           26.353434  1.387023   6.572067   9.115607  22.056890         20.0
# 4            7.792343  1.000000   3.750000   3.750000  53.616515         20.0
#
#    bitola
# 0     1.6
# 1     1.6
# 2     1.6
# 3     1.6
# 4     1.6

# %% [markdown]
# ## Direção longitudinal

# %% [markdown]
# ### Envoltorio dos momentos fletores

# %%
# Momento de dimensionamento

# Permanente
## Momento devido carga permamente - pegar valor Mym da tabela na secao 1.2 -
mg_long = df_g.iloc[5,0]
## Coeficiente seguranca
mg_long_coef = mg_long * 1.35

# Movel
# Momento devido carga movel - pegar valor do Mym no item 1.4
mq_long = df_q.iloc[0,1]
# Coeficiente de impacto vertical é o mesmo
psi
# Momento movel amplificado
mq_long_amp = mq_long * psi
# Coeficiente seguranca
mq_long_coef = mq_long_amp * 1.5

# MD
coeficiente_servico_tabuleiro = 0.8
md_long =  mg_long_coef + mq_long_coef
md_ser_long = mg_long + mq_long_amp * coeficiente_servico_tabuleiro

# Area de aco - formula na secao 1.4
bw = 100
d = 22
h = d + 3
alfa_e = 10
result = (md_to_as(md_long, bw, d, h, fcd, fs))
as_long = result[5]

# acha x - formula secao 1.4.7.
x_long = find_x(bw, alfa_e, as_long, d)

# Achar momento de inercia2 - formula secao 1.4.7.3
i_long = find_i(bw, x_long, as_long, alfa_e, d)

#Tensao AS
cobrimento = 3
tensao_as_long_inf = tensao_aco(alfa_e, md_ser_long, i_long, d, x_long) 
# tensao_as_long_sup = tensao_aco_neg(alfa_e, md_ser_long, i_long, cobrimento, x_long) #### ??? resultado nao bate com caderno
tensao_as_long_mg = tensao_aco(alfa_e, mg_long, i_long, d, x_long)
# tensao_as_long_mq = tensao_aco_neg(alfa_e, mq_long_amp, i_long, cobrimento, x_long)

# tabela
secoes_long = ['qualquer']
df_long = pd.DataFrame()
df_long['Secao'] = secoes_long
df_long['Mg'] = mg_long
df_long['Mq amplificado'] = mq_long_amp
df_long['Md'] = md_long
df_long['Md ser'] = md_ser_long
df_long['bw'] = bw
df_long['d'] = d
df_long['h'] = h
df_long['kmd'] = result[0]
df_long['kx'] = result[1]
df_long['kz'] = result[2]
df_long['as_prov'] = result[3]
df_long['as_min'] = result[4]
df_long['as_def'] = result[5]
df_long['x'] = x_long
df_long['I'] = i_long
df_long['T as pos, inf'] = tensao_as_long_inf
# df_long['T as neg, sup'] = tensao_as_long_sup
# df_long['T as pos, q'] = tensao_as_long_mq
df_long['T as pos, g'] = tensao_as_long_mg
df_long
# Out:
#       Secao        Mg  Mq amplificado        Md    Md ser   bw   d   h  \
# 0  qualquer  0.280285        0.378385  0.945962  0.582993  100  22  25
#
#         kmd        kx        kz   as_prov  as_min  as_def         x  \
# 0  0.006596  0.009704  0.996118  0.992814    3.75    3.75  3.704292
#
#               I  T as pos, inf  T as pos, g
# 0  14246.800821       7.486777     3.599412

# %%
# Verificacao fadiga

## Variacao de tensao
delta_long = tensao_as_long_inf - tensao_as_long_mg
delta_admis = 19 #kN/cm2 --> 190 MPa
k_fad_long = delta_long / delta_admis
## Nova area de aco
k_as_long = as_long * k_fad_long

# Espacamento
bitola = 1 #10 mm
## formula definida secao 1.4.7.5
esp_prov_long = espacamento(bitola, k_as_long)[0]
esp_adotado_long = espacamento(bitola, k_as_long)[1]

df_resumo_long = pd.DataFrame()
df_resumo_long['Tensao max'] = [tensao_as_long_inf]
df_resumo_long['Tensao min'] = [tensao_as_long_mg]
df_resumo_long['Variacao tensao as'] = [delta_long]
df_resumo_long['k fad'] = [k_fad_long]
df_resumo_long['As'] = as_long
df_resumo_long['k  As'] = k_as_long
df_resumo_long['esp prov'] = esp_prov_long
df_resumo_long['esp adotado'] = esp_adotado_long
df_resumo_long['bitola cm'] = bitola
df_resumo_long
# Out:
#    Tensao max  Tensao min  Variacao tensao as     k fad    As     k  As  \
# 0    7.486777    3.599412            3.887365  0.204598  3.75  0.767243
#
#      esp prov  esp adotado  bitola cm
# 0  102.366274           20          1

# %% [markdown]
# # Cálculo da laje em balanço

# %% [markdown]
# ## Esquema estrutural e seções de cálculo

# %% [markdown]
# ## Cargas permanentes

# %% [markdown]
# ### Cálculo das cargas

# %%
secoes_permanentes = [1,2,3,4,5,6,7,8]
# partes do guard rail
p1 = 0.175 * 0.87 * peso_concreto
p2 = 0.05 * 0.47 /2 * peso_concreto
p3 = 0.05 * 0.4 * peso_concreto
p4 = 0.175 * 0.25 /2 * peso_concreto
p5 = 0.175 * 0.15 * peso_concreto
# portes da laje em balanco
p6_s1 = 0.15 * 0.65 * peso_concreto
p6_s2 = 0.15 * 1.925 * peso_concreto
p6_s3 = 0.15 * 2.975 * peso_concreto
p7_s1 = 0.044 * 0.65/2 * peso_concreto
p7_s2 = 0.13 * 1.925/2 * peso_concreto
p7_s3 = 0.2 * 2.975/2 * peso_concreto
p8_s1 = 0.085 * 0.25 * peso_pavimento
p8_s2 = 0.085 * 1.525 * peso_pavimento
p8_s3 = 0.085 * 2.8 * peso_pavimento

p6 = p6_s1 + p6_s2 + p6_s3
p7 = p7_s1 + p7_s2 + p7_s3
p8 = p8_s1 + p8_s2 + p8_s3

pesos_permamentes_s1 = [p1,p2,p3,p4,p5,p6_s1,p7_s1,p8_s1]
pesos_permamentes_s2 = [p1,p2,p3,p4,p5,p6_s2,p7_s2,p8_s2]
pesos_permamentes_s3 = [p1,p2,p3,p4,p5,p6_s3,p7_s3,p8_s3]

# %% [markdown]
# ### Momentos fletores nas seções de cálculo, devido a carga permanente

# %% [markdown]
# #### Seção $S_1$

# %%
# distancias
d_s1 = [
    0.5625,
    0.4503,
    0.45,
    0.3667,
    0.3375,
    0.325,
    0.2167,
    0.125
       ]

# ATENCAO > TUDO EH MOMENTO NEGATIVO
# multiplicar d * p = m
momento_permamente_s1 = np.multiply(pesos_permamentes_s1, d_s1)
soma_momentos_s1 = -np.sum(momento_permamente_s1)
# print total soma momentos 
print(soma_momentos_s1)

# Tabela
df_secao_s1 = pd.DataFrame(index=secoes_permanentes)
df_secao_s1['P'] = pesos_permamentes_s1
df_secao_s1['d'] = d_s1
df_secao_s1['m (tf m/m)'] = -momento_permamente_s1
df_secao_s1.loc['Total']= df_secao_s1.sum()
df_secao_s1
# Out:
# -0.38537224375
#               P       d  m (tf m/m)
# 1      0.380625  0.5625   -0.214102
# 2      0.029375  0.4503   -0.013228
# 3      0.050000  0.4500   -0.022500
# 4      0.054688  0.3667   -0.020054
# 5      0.065625  0.3375   -0.022148
# 6      0.243750  0.3250   -0.079219
# 7      0.035750  0.2167   -0.007747
# 8      0.051000  0.1250   -0.006375
# Total  0.910813  2.8337   -0.385372

# %% [markdown]
# #### Seção $S_2$

# %%
# distancias
d_s2 = [
    1.8375,
    1.735,
    1.725,
    1.641,
    1.61,
    0.962,
    0.641,
    0.7625
       ]

# multiplicar d * p = m
momento_permamente_s2 = np.multiply(pesos_permamentes_s2, d_s2)
soma_momentos_s2 = -np.sum(momento_permamente_s2)
# print total soma momentos 
print(soma_momentos_s2)

# Tabela
df_secao_s2 = pd.DataFrame(index=secoes_permanentes)
df_secao_s2['P'] = pesos_permamentes_s2
df_secao_s2['d'] = d_s2
df_secao_s2['m (tf m/m)'] =-momento_permamente_s2
df_secao_s2.loc['Total']= df_secao_s2.sum()
df_secao_s2
# Out:
# -2.1641828125
#               P        d  m (tf m/m)
# 1      0.380625   1.8375   -0.699398
# 2      0.029375   1.7350   -0.050966
# 3      0.050000   1.7250   -0.086250
# 4      0.054688   1.6410   -0.089742
# 5      0.065625   1.6100   -0.105656
# 6      0.721875   0.9620   -0.694444
# 7      0.312813   0.6410   -0.200513
# 8      0.311100   0.7625   -0.237214
# Total  1.926100  10.9140   -2.164183

# %% [markdown]
# #### Seção $S_3$

# %%
# distancias
d_s3 = [
    3.113,
    3.008,
    3,
    2.917,
    2.887,
    1.713,
    1.217,
    1.4
       ]

# multiplicar d * p = m
momento_permamente_s3 = np.multiply(pesos_permamentes_s3, d_s3)
soma_momentos_s3 = -np.sum(momento_permamente_s3)
# print total soma momentos 
print(soma_momentos_s3)

# Tabela
df_secao_s3 = pd.DataFrame(index=secoes_permanentes)
df_secao_s3['P'] = pesos_permamentes_s3
df_secao_s3['d'] = d_s3
df_secao_s3['m (tf m/m)'] = -momento_permamente_s3
df_secao_s3.loc['Total']= df_secao_s3.sum()
df_secao_s3
# Out:
# -5.3881178125
#               P       d  m (tf m/m)
# 1      0.380625   3.113   -1.184886
# 2      0.029375   3.008   -0.088360
# 3      0.050000   3.000   -0.150000
# 4      0.054688   2.917   -0.159523
# 5      0.065625   2.887   -0.189459
# 6      1.115625   1.713   -1.911066
# 7      0.743750   1.217   -0.905144
# 8      0.571200   1.400   -0.799680
# Total  3.010887  19.255   -5.388118

# %% [markdown]
# ## Cargas móveis

# %% [markdown]
# ### Momento fletor nas seções de cálculo, devido a carga móvel

# %% [markdown]
# #### Direção transversal ('x')

# %% [markdown]
# #### Direção longitudinal ('y')

# %% [markdown]
# ## Direção transversal ('x')

# %% [markdown]
# ### Coeficiente de impacto vertical

# %% [markdown]
# ### Envoltório dos momentos fletores

# %% [markdown]
# ### Dimensionamento aos momentos fletores - direção ('y')

# %% [markdown]
# <img src="images/2.4.3.jpg" width="80%" />

# %% [markdown]
# <img src="images/2.4.3.1.jpg" width="80%" />

# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Exemplo:-Cálculo-da-laje-central" data-toc-modified-id="Exemplo:-Cálculo-da-laje-central-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exemplo: Cálculo da laje central</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Esquema-estrutural" data-toc-modified-id="Esquema-estrutural-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Esquema estrutural</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Cargas-permanentes" data-toc-modified-id="Cargas-permanentes-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Cargas permanentes</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-fletores-devido-carga-permanente" data-toc-modified-id="Momentos-fletores-devido-carga-permanente-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Momentos fletores devido carga permanente</a></span></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Carregamento-móvel" data-toc-modified-id="Carregamento-móvel-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Carregamento móvel</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Direção-transversal" data-toc-modified-id="Direção-transversal-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Direção transversal</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Diagramas-de-momentos-fletores" data-toc-modified-id="Diagramas-de-momentos-fletores-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Diagramas de momentos fletores</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-permanentes" data-toc-modified-id="Momentos-permanentes-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>Momentos permanentes</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-móveis" data-toc-modified-id="Momentos-móveis-1.4.1.2"><span class="toc-item-num">1.4.1.2&nbsp;&nbsp;</span>Momentos móveis</a></span></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Seção-transversal" data-toc-modified-id="Seção-transversal-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Seção transversal</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-fletores-nas-seções-de-cálculo-devido-a-carga-permanente" data-toc-modified-id="Momentos-fletores-nas-seções-de-cálculo-devido-a-carga-permanente-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Momentos fletores nas seções de cálculo devido a carga permanente</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momento-fletor-na-seção-de-cálculo,-devido-carga-móvel" data-toc-modified-id="Momento-fletor-na-seção-de-cálculo,-devido-carga-móvel-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Momento fletor na seção de cálculo, devido carga móvel</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Coeficiente-de-impacto-vertical" data-toc-modified-id="Coeficiente-de-impacto-vertical-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Coeficiente de impacto vertical</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Envoltório-momento-fletor" data-toc-modified-id="Envoltório-momento-fletor-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Envoltório momento fletor</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#DImensionamento-ao-momento-fletor" data-toc-modified-id="DImensionamento-ao-momento-fletor-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>DImensionamento ao momento fletor</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-positivos" data-toc-modified-id="Momentos-positivos-1.4.7.1"><span class="toc-item-num">1.4.7.1&nbsp;&nbsp;</span>Momentos positivos</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-negativos" data-toc-modified-id="Momentos-negativos-1.4.7.2"><span class="toc-item-num">1.4.7.2&nbsp;&nbsp;</span>Momentos negativos</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momento-positivos---Verificação-fadiga" data-toc-modified-id="Momento-positivos---Verificação-fadiga-1.4.7.3"><span class="toc-item-num">1.4.7.3&nbsp;&nbsp;</span>Momento positivos - Verificação fadiga</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-negativos---Verificação-fadiga" data-toc-modified-id="Momentos-negativos---Verificação-fadiga-1.4.7.4"><span class="toc-item-num">1.4.7.4&nbsp;&nbsp;</span>Momentos negativos - Verificação fadiga</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Resumo-armadura-positiva" data-toc-modified-id="Resumo-armadura-positiva-1.4.7.5"><span class="toc-item-num">1.4.7.5&nbsp;&nbsp;</span>Resumo armadura positiva</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Resumo-armadura-negativa" data-toc-modified-id="Resumo-armadura-negativa-1.4.7.6"><span class="toc-item-num">1.4.7.6&nbsp;&nbsp;</span>Resumo armadura negativa</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Direção-longitudinal" data-toc-modified-id="Direção-longitudinal-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Direção longitudinal</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Envoltorio-dos-momentos-fletores" data-toc-modified-id="Envoltorio-dos-momentos-fletores-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Envoltorio dos momentos fletores</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Cálculo-da-laje-em-balanço" data-toc-modified-id="Cálculo-da-laje-em-balanço-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cálculo da laje em balanço</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Esquema-estrutural-e-seções-de-cálculo" data-toc-modified-id="Esquema-estrutural-e-seções-de-cálculo-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Esquema estrutural e seções de cálculo</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Cargas-permanentes" data-toc-modified-id="Cargas-permanentes-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Cargas permanentes</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Cálculo-das-cargas" data-toc-modified-id="Cálculo-das-cargas-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Cálculo das cargas</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momentos-fletores-nas-seções-de-cálculo,-devido-a-carga-permanente" data-toc-modified-id="Momentos-fletores-nas-seções-de-cálculo,-devido-a-carga-permanente-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Momentos fletores nas seções de cálculo, devido a carga permanente</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Seção-$S_1$" data-toc-modified-id="Seção-$S_1$-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>Seção $S_1$</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Seção-$S_2$" data-toc-modified-id="Seção-$S_2$-2.2.2.2"><span class="toc-item-num">2.2.2.2&nbsp;&nbsp;</span>Seção $S_2$</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Seção-$S_3$" data-toc-modified-id="Seção-$S_3$-2.2.2.3"><span class="toc-item-num">2.2.2.3&nbsp;&nbsp;</span>Seção $S_3$</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Cargas-móveis" data-toc-modified-id="Cargas-móveis-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Cargas móveis</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Momento-fletor-nas-seções-de-cálculo,-devido-a-carga-móvel" data-toc-modified-id="Momento-fletor-nas-seções-de-cálculo,-devido-a-carga-móvel-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Momento fletor nas seções de cálculo, devido a carga móvel</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Direção-transversal-('x')" data-toc-modified-id="Direção-transversal-('x')-2.3.1.1"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>Direção transversal ('x')</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Direção-longitudinal-('y')" data-toc-modified-id="Direção-longitudinal-('y')-2.3.1.2"><span class="toc-item-num">2.3.1.2&nbsp;&nbsp;</span>Direção longitudinal ('y')</a></span></li></ul></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Direção-transversal-('x')" data-toc-modified-id="Direção-transversal-('x')-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Direção transversal ('x')</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Coeficiente-de-impacto-vertical" data-toc-modified-id="Coeficiente-de-impacto-vertical-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Coeficiente de impacto vertical</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Envoltório-dos-momentos-fletores" data-toc-modified-id="Envoltório-dos-momentos-fletores-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Envoltório dos momentos fletores</a></span></li><li><span><a href="http://localhost:8888/notebooks/Klassen/Pontes/Exemplo%20Ponte%20Viga%20-%20parte%201%20-%20Tabuleiro.ipynb#Dimensionamento-aos-momentos-fletores---direção-('y')" data-toc-modified-id="Dimensionamento-aos-momentos-fletores---direção-('y')-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Dimensionamento aos momentos fletores - direção ('y')</a></span></li></ul></li></ul></li></ul></div>
